# %% [markdown]
# # ＳＶＭ

# %%
#--------インポート--------
import numpy as np
from numpy.random import *
import random
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
#スクラッチでSVMを行うクラス
class ScratchSVMClassifier():

    """
    SVM分類器のスクラッチ実装
    """

    def __init__(self, num_iter, lr, bias, Threshold):#-------------------------
        self.iter = num_iter       #イテレーション回数
        self.lr = lr               #学習率
        self.bias = bias           #バイアス項
        self.Threshold = Threshold #しきい値

    #self.lambda_ラムダの一般式
    def _SVC_hypothesis(self, X, y):#-------------------------

        #yを2次元の配列に変更
        y = y.reshape(-1,1)

        #self.lambda_[i]はy.shape[0]の１００個あるので要素の数１００のラムダのndarrayを作る
        for i in range(y.shape[0]): #y.shape[0] = 100 yのデータ数だけ繰り返す

            #ダイバーの公式のΣ部分の初期値をゼロと定義する
            siguma = 0

            for j in range(len(y)): #len(y) = 100 #★☆★☆ｉとｊの数は同じだと思うが別にしている理由はあるか

                #ダイバーの公式のΣ部分.np.matmul(X[i].T, X[j])はカーネル関数
                siguma += self.lambda_[j] * y[i] * y[j] * np.matmul(X[i].T, X[j])

            #ダイバーの公式の最急降下法の式
            #self.lambda_[i] += self.lr * (1 - siguma)
            self.lambda_[i] = self.lambda_[i] +  self.lr * (1 - siguma)

            #self.lambda_が０以下の場合は０を代入する
            self.lambda_[self.lambda_ <= 0] = 0

        return self.lambda_

    def fit(self, X, y, X_val=None, y_val=None):#-------------------------

        """
        SVM分類器を学習します。
        検証データが入力されている場合は、そのデータに対する精度も反復ごとに計算されます。
        """
        #ランダム番号０
        np.random.seed(0)

        # λの初期値を設定
        self.lambda_ = np.random.rand(X.shape[0], 1) * 0.030 #np.random.randは0以上、1.0未満の(X.shape[0], 1)の配列の乱数　0.030は

        #イテレーション回数繰り返す
        for i in range(self.iter):#イテレーション回数ｉを繰り返す

            #ラムダ一般式を呼び出すメソッド
            self._SVC_hypothesis(X, y)
            # print("イテレーション回数i:{}".format(i)) #------検証中--------
            # print("self.lambda_:{}".format(self.lambda_)) #------検証中--------
            # print("self.lambda_.shape:{}".format(self.lambda_.shape)) #------検証中--------#self.lambda_.shape:(22, 1)
            # print("X.shape:{}".format(X.shape)) #------検証中--------
            # print("y.shape:{}".format(y.shape)) #------検証中--------

        # ------------サポートベクターの抽出、仕様------------

        # self.index_lという空のリストを作り、しきい値より大きいラムダの要素番号をself.index_lに追加していく
        self.index_l = []

        #ラムダの値と要素番号を出力してしきい値より高いものの要素番号をサポートベクターとしてリストに追加
        for j, i in enumerate(self.lambda_):        #enumerateはタプル（インデックス、要素）でｊに要素の番号、ｉに要素を出力する
            if i > self.Threshold:                  #もしラムダの要素がしきい値より大きければ
                self.index_l .append(j)             #大きい閾値の要素番号をself.index_lに格納

        #self.lambda_svは全部のラムダのndarrayからしきい値より大きいラムダのみを抽出したリスト
        self.lambda_sv = self.lambda_[self.index_l]

        #self.X_svは全部のXからラムダがしきい値よりXのみを抽出したリスト（黄色のプロットになる値）サポートベクター
        self.X_sv = X[self.index_l]
        #self.y_svは全部のyからラムダがしきい値よりyのみを抽出したリスト（黄色のプロットになる値）サポートベクター
        self.y_sv = y[self.index_l]

        print("テストデータXのサポートベクターself.X_sv:{}".format(self.X_sv)) #------検証中--------
        print("テストデータｙのサポートベクターself.y_sv:{}".format(self.y_sv)) #------検証中--------


    #ｙの予測値を出力
    def predict(self, X):#-------------------------

        """
        SVM分類器を使ってラベルを推定します。テストデータを引数Xに代入する
        """

        #初期値をゼロとする
        self.y_pred = 0

        #しきい値より大きいラムダのリストのデータ数をｉとし、ダイバーのy_predの一般式にサポートベクターのself.lambda_svとサポートベクターself.X_sv、サポートベクターself.y_svを代入し最適化Ｘ
        for i in range(self.lambda_sv.shape[0]):
             self.y_pred += self.lambda_sv[i] * self.y_sv[i] * np.dot(X, self.X_sv[i].T) #ダイバーのy_predの公式

        #self.y_predが０より大きければ１、そうでなければ－１をself.y_predに代入しself.y_predを完成させる。
        self.y_pred = np.where(self.y_pred > 0, 1, -1)

        return self.y_pred

# %%
#-----------検証用データ-----------

import numpy as np
np.random.seed(seed=0)
n_samples = 30
f0 = [-1, 2]
f1 = [2, -1]
cov = [[1.0,0.8], [0.8, 1.0]]
f0 = np.random.multivariate_normal(f0, cov, n_samples // 2)
f1 = np.random.multivariate_normal(f1, cov, n_samples // 2)
X = np.concatenate([f0, f1])
y = np.concatenate([
    np.full(n_samples // 2, 1),
    np.full(n_samples // 2, -1)
])

print("検証用データX.shape:{}".format(X.shape)) #------検証中--------
print("検証用データy.shape:{}".format(y.shape)) #------検証中--------
print("検証用データX:{}".format(X)) #------検証中--------
print("検証用データy:{}".format(y)) #------検証中--------

random_index = np.random.permutation(np.arange(n_samples))
X = X[random_index]
y = y[random_index]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
#--------境界線を描く関数--------

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
def decision_region(X, y, model, step=0.01, title='decision region', xlabel='xlabel', ylabel='ylabel', target_names=['versicolor', 'virginica']):

    # setting
    scatter_color = ['red', 'blue']
    contourf_color = ['pink', 'skyblue']
    n_class = 2

    # pred
    mesh_f0, mesh_f1  = np.meshgrid(np.arange(np.min(X[:,0])-0.5, np.max(X[:,0])+0.5, step), np.arange(np.min(X[:,1])-0.5, np.max(X[:,1])+0.5, step))
    mesh = np.c_[np.ravel(mesh_f0),np.ravel(mesh_f1)]
    y_pred = model.predict(mesh).reshape(mesh_f0.shape)

    # plot
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.contourf(mesh_f0, mesh_f1, y_pred, n_class-1, cmap=ListedColormap(contourf_color))
    plt.contour(mesh_f0, mesh_f1, y_pred, n_class-1, colors='y', linewidths=3, alpha=0.5)
    for i, target in enumerate(set(y)):
        plt.scatter(X[y==target][:, 0], X[y==target][:, 1], s=80, color=scatter_color[i], label=target_names[i], marker='o')
    if model==SV:
        plt.scatter(SV.X_sv[:, 0], SV.X_sv[:, 1], s=80, color='yellow', marker='o')
    else:
        plt.scatter(X_train[svc.support_, 0], X_train[svc.support_, 1], s=80, color='yellow', marker='o')
    patches = [mpatches.Patch(color=scatter_color[i], label=target_names[i]) for i in range(n_class)]
    plt.legend(handles=patches)
    plt.legend()

# %%
# print("--------Scikit-learnのSVMモジュール--------")
# from sklearn.svm import SVC
# svc = SVC(random_state=0, C=1e10, kernel='linear')
# svc.fit(X_train, y_train)
# svc_pred = svc.predict(X_test)

# #--------境界線を描く関数decision_regionの呼び出し--------
# decision_region(X_train, y_train, svc, step=0.01, title='With Sklearn', xlabel='xlabel', ylabel='ylabel', target_names=["A" ,'B'])

# %%
print("--------スクラッチSVMモジュール--------")
SV = ScratchSVMClassifier(num_iter=100, lr=0.01, bias=True ,Threshold=1e-5)
SV.fit(X_train, y_train, X_test, y_test)

#SVインスタンスに、Xテストデータの予測値をSV_predとしてメソッド呼び出し
SV_pred = SV.predict(X_test)
print("SV_pred:{}".format(SV_pred)) #------検証中--------

#--------境界線を描く関数decision_regionの呼び出し--------
decision_region(X, y, SV, step=0.01, title='ScratchLogisticRegression', xlabel='xlabel', ylabel='ylabel', target_names=["A" ,'B'])
# Out:
# --------スクラッチSVMモジュール--------
# イテレーション回数i:0
# self.lambda_:[[0.00923262]
#  [0.01229502]
#  [0.00428904]
#  [0.01543948]
#  [0.00284369]
#  [0.00065595]
#  [0.00789975]
#  [0.0135816 ]
#  [0.02246968]
#  [0.00692585]
#  [0.01172168]
#  [0.01322334]
#  [0.01088128]
#  [0.02403701]
#  [0.00147687]
#  [0.        ]
#  [0.        ]
#  [0.01492399]
#  [0.02132092]
#  [0.02288142]
#  [0.02632837]
#  [0.02428184]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:1
# self.lambda_:[[0.00854176]
#  [0.01034246]
#  [0.        ]
#  [0.01745671]
#  [0.00030343]
#  [0.        ]
#  [0.00847176]
#  [0.00702249]
#  [0.02112745]
#  [0.00607666]
#  [0.005512  ]
#  [0.01311409]
#  [0.00852976]
#  [0.02324973]
#  [0.00280445]
#  [0.        ]
#  [0.        ]
#  [0.00864691]
#  [0.02148176]
#  [0.02223772]
#  [0.02526854]
#  [0.02465728]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:2
# self.lambda_:[[0.00958014]
#  [0.01029837]
#  [0.        ]
#  [0.02017567]
#  [0.        ]
#  [0.        ]
#  [0.01087976]
#  [0.00248468]
#  [0.02137961]
#  [0.00636069]
#  [0.00109666]
#  [0.0137397 ]
#  [0.00734352]
#  [0.023351  ]
#  [0.0047116 ]
#  [0.        ]
#  [0.        ]
#  [0.00358293]
#  [0.02234513]
#  [0.02242832]
#  [0.0248366 ]
#  [0.02501749]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:3
# self.lambda_:[[0.01117546]
#  [0.01086965]
#  [0.        ]
#  [0.02314211]
#  [0.        ]
#  [0.        ]
#  [0.01404465]
#  [0.        ]
#  [0.02218214]
#  [0.00702415]
#  [0.        ]
#  [0.01448315]
#  [0.00631595]
#  [0.02357857]
#  [0.00670942]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02322477]
#  [0.0226399 ]
#  [0.02441764]
#  [0.02536729]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:4
# self.lambda_:[[1.27838988e-02]
#  [1.14556231e-02]
#  [0.00000000e+00]
#  [2.61121894e-02]
#  [1.18241294e-06]
#  [0.00000000e+00]
#  [1.72320969e-02]
#  [0.00000000e+00]
#  [2.28021874e-02]
#  [7.55213056e-03]
#  [0.00000000e+00]
#  [1.50767715e-02]
#  [5.03741533e-03]
#  [2.36172902e-02]
#  [8.58798888e-03]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [2.37093623e-02]
#  [2.24079372e-02]
#  [2.36217082e-02]
#  [2.55710327e-02]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:5
# self.lambda_:[[0.01408267]
#  [0.01170234]
#  [0.        ]
#  [0.02891082]
#  [0.        ]
#  [0.        ]
#  [0.0200555 ]
#  [0.        ]
#  [0.0230559 ]
#  [0.00779604]
#  [0.        ]
#  [0.01544149]
#  [0.00343518]
#  [0.02340179]
#  [0.0102892 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02397051]
#  [0.021925  ]
#  [0.02261264]
#  [0.0256927 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:6
# self.lambda_:[[0.01520627]
#  [0.01175713]
#  [0.        ]
#  [0.03161258]
#  [0.        ]
#  [0.        ]
#  [0.02267258]
#  [0.        ]
#  [0.0231021 ]
#  [0.00787914]
#  [0.        ]
#  [0.01567676]
#  [0.00164967]
#  [0.0230424 ]
#  [0.01189008]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02410518]
#  [0.02129994]
#  [0.02148299]
#  [0.02576831]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:7
# self.lambda_:[[0.01623071]
#  [0.01170328]
#  [0.        ]
#  [0.0342596 ]
#  [0.        ]
#  [0.        ]
#  [0.02517274]
#  [0.        ]
#  [0.02303075]
#  [0.00787125]
#  [0.        ]
#  [0.01583884]
#  [0.        ]
#  [0.02258881]
#  [0.01342611]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02415708]
#  [0.02058104]
#  [0.02027521]
#  [0.0258188 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:8
# self.lambda_:[[0.01719014]
#  [0.01157811]
#  [0.        ]
#  [0.03687184]
#  [0.        ]
#  [0.        ]
#  [0.02759404]
#  [0.        ]
#  [0.02288095]
#  [0.00780363]
#  [0.        ]
#  [0.01595391]
#  [0.        ]
#  [0.02199035]
#  [0.01486731]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02408176]
#  [0.01971293]
#  [0.01895198]
#  [0.02586075]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:9
# self.lambda_:[[0.01804899]
#  [0.01134201]
#  [0.        ]
#  [0.03943691]
#  [0.        ]
#  [0.        ]
#  [0.0298802 ]
#  [0.        ]
#  [0.02260141]
#  [0.00764326]
#  [0.        ]
#  [0.01600199]
#  [0.        ]
#  [0.02130417]
#  [0.01625187]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02392944]
#  [0.01875369]
#  [0.01755962]
#  [0.02590241]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:10
# self.lambda_:[[0.01884682]
#  [0.01103853]
#  [0.        ]
#  [0.04197444]
#  [0.        ]
#  [0.        ]
#  [0.03208227]
#  [0.        ]
#  [0.02224183]
#  [0.00742656]
#  [0.        ]
#  [0.01601036]
#  [0.        ]
#  [0.02056484]
#  [0.01760266]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02373046]
#  [0.0177387 ]
#  [0.0161259 ]
#  [0.02594718]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:11
# self.lambda_:[[0.01960762]
#  [0.0106941 ]
#  [0.        ]
#  [0.04449597]
#  [0.        ]
#  [0.        ]
#  [0.03423188]
#  [0.        ]
#  [0.02183278]
#  [0.00717564]
#  [0.        ]
#  [0.01599526]
#  [0.        ]
#  [0.01979329]
#  [0.01893333]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02350322]
#  [0.01668957]
#  [0.01466744]
#  [0.02599603]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:12
# self.lambda_:[[0.02034594]
#  [0.01032476]
#  [0.        ]
#  [0.04700827]
#  [0.        ]
#  [0.        ]
#  [0.03634869]
#  [0.        ]
#  [0.02139308]
#  [0.00690391]
#  [0.        ]
#  [0.01596631]
#  [0.        ]
#  [0.0190022 ]
#  [0.02025205]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02325883]
#  [0.0156195 ]
#  [0.01319423]
#  [0.02604882]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:13
# self.lambda_:[[0.02107059]
#  [0.00994025]
#  [0.        ]
#  [0.04951528]
#  [0.        ]
#  [0.        ]
#  [0.03844492]
#  [0.        ]
#  [0.02093435]
#  [0.00661953]
#  [0.        ]
#  [0.01592924]
#  [0.        ]
#  [0.01819926]
#  [0.02156366]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02300405]
#  [0.01453655]
#  [0.0117122 ]
#  [0.026105  ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:14
# self.lambda_:[[0.02178692]
#  [0.00954649]
#  [0.        ]
#  [0.05201928]
#  [0.        ]
#  [0.        ]
#  [0.04052821]
#  [0.        ]
#  [0.02046376]
#  [0.00632742]
#  [0.        ]
#  [0.0158874 ]
#  [0.        ]
#  [0.01738912]
#  [0.02287108]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02274296]
#  [0.01344568]
#  [0.01022494]
#  [0.0261639 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:15
# self.lambda_:[[0.02249819]
#  [0.00914709]
#  [0.        ]
#  [0.0545216 ]
#  [0.        ]
#  [0.        ]
#  [0.04260334]
#  [0.        ]
#  [0.01998579]
#  [0.00603061]
#  [0.        ]
#  [0.01584279]
#  [0.        ]
#  [0.0165746 ]
#  [0.02417602]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02247803]
#  [0.01234992]
#  [0.00873456]
#  [0.0262249 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:16
# self.lambda_:[[0.02320638]
#  [0.00874425]
#  [0.        ]
#  [0.05702299]
#  [0.        ]
#  [0.        ]
#  [0.0446733 ]
#  [0.        ]
#  [0.01950319]
#  [0.00573093]
#  [0.        ]
#  [0.01579657]
#  [0.        ]
#  [0.01575743]
#  [0.0254795 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02221078]
#  [0.01125115]
#  [0.00724233]
#  [0.02628746]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:17
# self.lambda_:[[0.02391268]
#  [0.0083393 ]
#  [0.        ]
#  [0.05952388]
#  [0.        ]
#  [0.        ]
#  [0.04673999]
#  [0.        ]
#  [0.01901768]
#  [0.00542949]
#  [0.        ]
#  [0.01574942]
#  [0.        ]
#  [0.01493863]
#  [0.02678212]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0219421 ]
#  [0.0101505 ]
#  [0.00574901]
#  [0.02635117]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:18
# self.lambda_:[[0.02461784]
#  [0.00793305]
#  [0.        ]
#  [0.0620245 ]
#  [0.        ]
#  [0.        ]
#  [0.04880458]
#  [0.        ]
#  [0.01853035]
#  [0.00512698]
#  [0.        ]
#  [0.01570175]
#  [0.        ]
#  [0.01411885]
#  [0.02808423]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02167256]
#  [0.0090487 ]
#  [0.00425504]
#  [0.02641573]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:19
# self.lambda_:[[0.02532229]
#  [0.00752602]
#  [0.        ]
#  [0.06452498]
#  [0.        ]
#  [0.        ]
#  [0.05086785]
#  [0.        ]
#  [0.01804186]
#  [0.00482381]
#  [0.        ]
#  [0.01565378]
#  [0.        ]
#  [0.01329846]
#  [0.02938606]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0214025 ]
#  [0.00794617]
#  [0.00276069]
#  [0.02648087]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:20
# self.lambda_:[[0.02602631]
#  [0.00711849]
#  [0.        ]
#  [0.0670254 ]
#  [0.        ]
#  [0.        ]
#  [0.05293026]
#  [0.        ]
#  [0.01755264]
#  [0.00452023]
#  [0.        ]
#  [0.01560564]
#  [0.        ]
#  [0.01247771]
#  [0.03068772]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02113211]
#  [0.00684319]
#  [0.00126612]
#  [0.02654645]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:21
# self.lambda_:[[0.02673007]
#  [0.00671067]
#  [0.        ]
#  [0.0695258 ]
#  [0.        ]
#  [0.        ]
#  [0.05499212]
#  [0.        ]
#  [0.01706296]
#  [0.00421641]
#  [0.        ]
#  [0.01555741]
#  [0.        ]
#  [0.01165673]
#  [0.03198929]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02086153]
#  [0.00573993]
#  [0.        ]
#  [0.02659874]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:22
# self.lambda_:[[0.02742482]
#  [0.00629315]
#  [0.        ]
#  [0.07201923]
#  [0.        ]
#  [0.        ]
#  [0.05704731]
#  [0.        ]
#  [0.01656512]
#  [0.00390443]
#  [0.        ]
#  [0.01550081]
#  [0.        ]
#  [0.01082774]
#  [0.03328431]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02058389]
#  [0.0046297 ]
#  [0.        ]
#  [0.02656693]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:23
# self.lambda_:[[0.02806492]
#  [0.00581686]
#  [0.        ]
#  [0.07446964]
#  [0.        ]
#  [0.        ]
#  [0.05906347]
#  [0.        ]
#  [0.01601862]
#  [0.00354297]
#  [0.        ]
#  [0.01539273]
#  [0.        ]
#  [0.00995009]
#  [0.03453925]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02026335]
#  [0.00347753]
#  [0.        ]
#  [0.02647896]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:24
# self.lambda_:[[0.02867043]
#  [0.00530342]
#  [0.        ]
#  [0.07689216]
#  [0.        ]
#  [0.        ]
#  [0.06105623]
#  [0.        ]
#  [0.01544216]
#  [0.00315025]
#  [0.        ]
#  [0.01525151]
#  [0.        ]
#  [0.00904161]
#  [0.03576846]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01991563]
#  [0.0022991 ]
#  [0.        ]
#  [0.02635344]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:25
# self.lambda_:[[0.02925407]
#  [0.00476652]
#  [0.        ]
#  [0.07929662]
#  [0.        ]
#  [0.        ]
#  [0.06303504]
#  [0.        ]
#  [0.01484729]
#  [0.00273777]
#  [0.        ]
#  [0.01508895]
#  [0.        ]
#  [0.00811361]
#  [0.03698118]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01955069]
#  [0.00110424]
#  [0.        ]
#  [0.0262028 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:26
# self.lambda_:[[0.02982386]
#  [0.00421481]
#  [0.        ]
#  [0.08168934]
#  [0.        ]
#  [0.        ]
#  [0.06500563]
#  [0.        ]
#  [0.01424115]
#  [0.0023128 ]
#  [0.        ]
#  [0.01491263]
#  [0.        ]
#  [0.00717323]
#  [0.03818329]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01917484]
#  [0.        ]
#  [0.        ]
#  [0.02603582]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:27
# self.lambda_:[[0.03038063]
#  [0.00364902]
#  [0.        ]
#  [0.08407261]
#  [0.        ]
#  [0.        ]
#  [0.06696531]
#  [0.        ]
#  [0.0136224 ]
#  [0.001876  ]
#  [0.        ]
#  [0.01472474]
#  [0.        ]
#  [0.00622129]
#  [0.03937627]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01878881]
#  [0.        ]
#  [0.        ]
#  [0.02586311]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:28
# self.lambda_:[[0.03088201]
#  [0.00302216]
#  [0.        ]
#  [0.08642968]
#  [0.        ]
#  [0.        ]
#  [0.06885101]
#  [0.        ]
#  [0.01293248]
#  [0.00138812]
#  [0.        ]
#  [0.01449976]
#  [0.        ]
#  [0.00522104]
#  [0.04053796]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01836036]
#  [0.        ]
#  [0.        ]
#  [0.02568751]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:29
# self.lambda_:[[0.03134619]
#  [0.00235429]
#  [0.        ]
#  [0.08876938]
#  [0.        ]
#  [0.        ]
#  [0.07068663]
#  [0.        ]
#  [0.01219453]
#  [0.00086595]
#  [0.        ]
#  [0.01425007]
#  [0.        ]
#  [0.00418836]
#  [0.04167873]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01790344]
#  [0.        ]
#  [0.        ]
#  [0.02551064]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:30
# self.lambda_:[[0.03178541]
#  [0.00165886]
#  [0.        ]
#  [0.09109754]
#  [0.        ]
#  [0.        ]
#  [0.07248833]
#  [0.        ]
#  [0.01142414]
#  [0.00032074]
#  [0.        ]
#  [0.0139839 ]
#  [0.        ]
#  [0.0031339 ]
#  [0.04280555]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01742741]
#  [0.        ]
#  [0.        ]
#  [0.02533335]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:31
# self.lambda_:[[0.03220785]
#  [0.00094492]
#  [0.        ]
#  [0.09341806]
#  [0.        ]
#  [0.        ]
#  [0.07426708]
#  [0.        ]
#  [0.01063184]
#  [0.        ]
#  [0.        ]
#  [0.01369848]
#  [0.        ]
#  [0.00205463]
#  [0.04391616]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01692958]
#  [0.        ]
#  [0.        ]
#  [0.02515378]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:32
# self.lambda_:[[0.03261121]
#  [0.00020994]
#  [0.        ]
#  [0.09572949]
#  [0.        ]
#  [0.        ]
#  [0.07602046]
#  [0.        ]
#  [0.00981511]
#  [0.        ]
#  [0.        ]
#  [0.01338855]
#  [0.        ]
#  [0.00094432]
#  [0.04500624]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01640449]
#  [0.        ]
#  [0.        ]
#  [0.0249698 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:33
# self.lambda_:[[0.03299074]
#  [0.        ]
#  [0.        ]
#  [0.09801509]
#  [0.        ]
#  [0.        ]
#  [0.07771885]
#  [0.        ]
#  [0.00894307]
#  [0.        ]
#  [0.        ]
#  [0.01304263]
#  [0.        ]
#  [0.        ]
#  [0.04605957]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01583308]
#  [0.        ]
#  [0.        ]
#  [0.02476659]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:34
# self.lambda_:[[0.03333002]
#  [0.        ]
#  [0.        ]
#  [0.10027185]
#  [0.        ]
#  [0.        ]
#  [0.07935897]
#  [0.        ]
#  [0.00801185]
#  [0.        ]
#  [0.        ]
#  [0.01265693]
#  [0.        ]
#  [0.        ]
#  [0.04704651]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01517931]
#  [0.        ]
#  [0.        ]
#  [0.02452241]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:35
# self.lambda_:[[0.03359795]
#  [0.        ]
#  [0.        ]
#  [0.10248551]
#  [0.        ]
#  [0.        ]
#  [0.08091494]
#  [0.        ]
#  [0.00699464]
#  [0.        ]
#  [0.        ]
#  [0.01221215]
#  [0.        ]
#  [0.        ]
#  [0.04798281]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01446252]
#  [0.        ]
#  [0.        ]
#  [0.02424792]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:36
# self.lambda_:[[0.03381126]
#  [0.        ]
#  [0.        ]
#  [0.10466639]
#  [0.        ]
#  [0.        ]
#  [0.08240604]
#  [0.        ]
#  [0.00591129]
#  [0.        ]
#  [0.        ]
#  [0.01172233]
#  [0.        ]
#  [0.        ]
#  [0.04888045]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01369751]
#  [0.        ]
#  [0.        ]
#  [0.02395091]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:37
# self.lambda_:[[0.03398273]
#  [0.        ]
#  [0.        ]
#  [0.10682233]
#  [0.        ]
#  [0.        ]
#  [0.08384716]
#  [0.        ]
#  [0.00477711]
#  [0.        ]
#  [0.        ]
#  [0.01119817]
#  [0.        ]
#  [0.        ]
#  [0.04974859]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01289557]
#  [0.        ]
#  [0.        ]
#  [0.02363716]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:38
# self.lambda_:[[0.03412218]
#  [0.        ]
#  [0.        ]
#  [0.10895929]
#  [0.        ]
#  [0.        ]
#  [0.0852498 ]
#  [0.        ]
#  [0.00360388]
#  [0.        ]
#  [0.        ]
#  [0.0106478 ]
#  [0.        ]
#  [0.        ]
#  [0.05059419]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01206537]
#  [0.        ]
#  [0.        ]
#  [0.02331091]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:39
# self.lambda_:[[0.0342371 ]
#  [0.        ]
#  [0.        ]
#  [0.11108177]
#  [0.        ]
#  [0.        ]
#  [0.08662282]
#  [0.        ]
#  [0.00240064]
#  [0.        ]
#  [0.        ]
#  [0.01007743]
#  [0.        ]
#  [0.        ]
#  [0.05142256]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01121353]
#  [0.        ]
#  [0.        ]
#  [0.02297531]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:40
# self.lambda_:[[0.03433323]
#  [0.        ]
#  [0.        ]
#  [0.11319321]
#  [0.        ]
#  [0.        ]
#  [0.08797306]
#  [0.        ]
#  [0.00117437]
#  [0.        ]
#  [0.        ]
#  [0.00949176]
#  [0.        ]
#  [0.        ]
#  [0.05223777]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01034512]
#  [0.        ]
#  [0.        ]
#  [0.0226327 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:41
# self.lambda_:[[0.03441498]
#  [0.        ]
#  [0.        ]
#  [0.11529624]
#  [0.        ]
#  [0.        ]
#  [0.0893058 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00889298]
#  [0.        ]
#  [0.        ]
#  [0.05304129]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00946088]
#  [0.        ]
#  [0.        ]
#  [0.02228899]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:42
# self.lambda_:[[0.03448285]
#  [0.        ]
#  [0.        ]
#  [0.11739239]
#  [0.        ]
#  [0.        ]
#  [0.09061919]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00825929]
#  [0.        ]
#  [0.        ]
#  [0.05380807]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00851075]
#  [0.        ]
#  [0.        ]
#  [0.02201548]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:43
# self.lambda_:[[0.03449122]
#  [0.        ]
#  [0.        ]
#  [0.11947539]
#  [0.        ]
#  [0.        ]
#  [0.09181714]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00759394]
#  [0.        ]
#  [0.        ]
#  [0.05454248]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00750486]
#  [0.        ]
#  [0.        ]
#  [0.02179335]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:44
# self.lambda_:[[0.03444941]
#  [0.        ]
#  [0.        ]
#  [0.1215456 ]
#  [0.        ]
#  [0.        ]
#  [0.09292112]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00690048]
#  [0.        ]
#  [0.        ]
#  [0.05524873]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00645195]
#  [0.        ]
#  [0.        ]
#  [0.02160917]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:45
# self.lambda_:[[0.03436542]
#  [0.        ]
#  [0.        ]
#  [0.12360391]
#  [0.        ]
#  [0.        ]
#  [0.0939484 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00618242]
#  [0.        ]
#  [0.        ]
#  [0.05593073]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00535951]
#  [0.        ]
#  [0.        ]
#  [0.02145322]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:46
# self.lambda_:[[0.03424606]
#  [0.        ]
#  [0.        ]
#  [0.12565146]
#  [0.        ]
#  [0.        ]
#  [0.09491289]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00544307]
#  [0.        ]
#  [0.        ]
#  [0.05659199]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00423393]
#  [0.        ]
#  [0.        ]
#  [0.02131846]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:47
# self.lambda_:[[0.03409709]
#  [0.        ]
#  [0.        ]
#  [0.12768947]
#  [0.        ]
#  [0.        ]
#  [0.09582591]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00468545]
#  [0.        ]
#  [0.        ]
#  [0.05723563]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00308059]
#  [0.        ]
#  [0.        ]
#  [0.02119974]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:48
# self.lambda_:[[0.03392338]
#  [0.        ]
#  [0.        ]
#  [0.12971914]
#  [0.        ]
#  [0.        ]
#  [0.09669661]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00391227]
#  [0.        ]
#  [0.        ]
#  [0.05786436]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00190406]
#  [0.        ]
#  [0.        ]
#  [0.02109329]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:49
# self.lambda_:[[0.03372902]
#  [0.        ]
#  [0.        ]
#  [0.1317416 ]
#  [0.        ]
#  [0.        ]
#  [0.0975325 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00312588]
#  [0.        ]
#  [0.        ]
#  [0.05848051]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00070818]
#  [0.        ]
#  [0.        ]
#  [0.02099628]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:50
# self.lambda_:[[0.03351743]
#  [0.        ]
#  [0.        ]
#  [0.13375788]
#  [0.        ]
#  [0.        ]
#  [0.09833969]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00232835]
#  [0.        ]
#  [0.        ]
#  [0.0590861 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02089325]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:51
# self.lambda_:[[0.03327309]
#  [0.        ]
#  [0.        ]
#  [0.13575717]
#  [0.        ]
#  [0.        ]
#  [0.09910271]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00150521]
#  [0.        ]
#  [0.        ]
#  [0.05966893]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02076797]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:52
# self.lambda_:[[0.03297485]
#  [0.        ]
#  [0.        ]
#  [0.1377258 ]
#  [0.        ]
#  [0.        ]
#  [0.09979839]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0006377 ]
#  [0.        ]
#  [0.        ]
#  [0.06021296]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02062838]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:53
# self.lambda_:[[0.0326307 ]
#  [0.        ]
#  [0.        ]
#  [0.13966932]
#  [0.        ]
#  [0.        ]
#  [0.10043471]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06071451]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02046009]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:54
# self.lambda_:[[0.0322392 ]
#  [0.        ]
#  [0.        ]
#  [0.14158391]
#  [0.        ]
#  [0.        ]
#  [0.10101584]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06115565]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02022279]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:55
# self.lambda_:[[0.03178674]
#  [0.        ]
#  [0.        ]
#  [0.14345424]
#  [0.        ]
#  [0.        ]
#  [0.10153984]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0615459 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01993457]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:56
# self.lambda_:[[0.03128129]
#  [0.        ]
#  [0.        ]
#  [0.14528808]
#  [0.        ]
#  [0.        ]
#  [0.10201024]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06189296]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01960852]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:57
# self.lambda_:[[0.03072966]
#  [0.        ]
#  [0.        ]
#  [0.14709156]
#  [0.        ]
#  [0.        ]
#  [0.10243109]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06220316]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01925412]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:58
# self.lambda_:[[0.03013774]
#  [0.        ]
#  [0.        ]
#  [0.14886954]
#  [0.        ]
#  [0.        ]
#  [0.10280669]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06248175]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01887828]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:59
# self.lambda_:[[0.0295106 ]
#  [0.        ]
#  [0.        ]
#  [0.15062599]
#  [0.        ]
#  [0.        ]
#  [0.10314128]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06273308]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01848606]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:60
# self.lambda_:[[0.02885264]
#  [0.        ]
#  [0.        ]
#  [0.15236411]
#  [0.        ]
#  [0.        ]
#  [0.10343897]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06296086]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01808119]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:61
# self.lambda_:[[0.0281677 ]
#  [0.        ]
#  [0.        ]
#  [0.15408655]
#  [0.        ]
#  [0.        ]
#  [0.1037036 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06316821]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01766645]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:62
# self.lambda_:[[0.02745911]
#  [0.        ]
#  [0.        ]
#  [0.15579551]
#  [0.        ]
#  [0.        ]
#  [0.10393873]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06335779]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01724391]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:63
# self.lambda_:[[0.02672978]
#  [0.        ]
#  [0.        ]
#  [0.15749284]
#  [0.        ]
#  [0.        ]
#  [0.10414762]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06353189]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01681514]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:64
# self.lambda_:[[0.02598225]
#  [0.        ]
#  [0.        ]
#  [0.1591801 ]
#  [0.        ]
#  [0.        ]
#  [0.10433323]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06369249]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01638133]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:65
# self.lambda_:[[0.02521875]
#  [0.        ]
#  [0.        ]
#  [0.16085861]
#  [0.        ]
#  [0.        ]
#  [0.1044982 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06384127]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0159434 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:66
# self.lambda_:[[0.02444123]
#  [0.        ]
#  [0.        ]
#  [0.16252951]
#  [0.        ]
#  [0.        ]
#  [0.10464493]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06397973]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01550208]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:67
# self.lambda_:[[0.02365139]
#  [0.        ]
#  [0.        ]
#  [0.16419378]
#  [0.        ]
#  [0.        ]
#  [0.10477554]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06410914]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01505794]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:68
# self.lambda_:[[0.02285073]
#  [0.        ]
#  [0.        ]
#  [0.16585224]
#  [0.        ]
#  [0.        ]
#  [0.10489192]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06423063]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01461143]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:69
# self.lambda_:[[0.02204057]
#  [0.        ]
#  [0.        ]
#  [0.16750564]
#  [0.        ]
#  [0.        ]
#  [0.10499576]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06434516]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01416291]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:70
# self.lambda_:[[0.02122205]
#  [0.        ]
#  [0.        ]
#  [0.16915461]
#  [0.        ]
#  [0.        ]
#  [0.10508853]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06445359]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01371268]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:71
# self.lambda_:[[0.0203962 ]
#  [0.        ]
#  [0.        ]
#  [0.17079968]
#  [0.        ]
#  [0.        ]
#  [0.10517156]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06455666]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.013261  ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:72
# self.lambda_:[[0.01956389]
#  [0.        ]
#  [0.        ]
#  [0.17244135]
#  [0.        ]
#  [0.        ]
#  [0.105246  ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06465504]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01280805]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:73
# self.lambda_:[[0.01872591]
#  [0.        ]
#  [0.        ]
#  [0.17408004]
#  [0.        ]
#  [0.        ]
#  [0.1053129 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06474928]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01235403]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:74
# self.lambda_:[[0.01788295]
#  [0.        ]
#  [0.        ]
#  [0.17571609]
#  [0.        ]
#  [0.        ]
#  [0.10537314]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0648399 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01189906]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:75
# self.lambda_:[[0.0170356 ]
#  [0.        ]
#  [0.        ]
#  [0.17734985]
#  [0.        ]
#  [0.        ]
#  [0.10542753]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06492733]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01144328]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:76
# self.lambda_:[[0.01618441]
#  [0.        ]
#  [0.        ]
#  [0.17898159]
#  [0.        ]
#  [0.        ]
#  [0.10547677]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06501196]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01098679]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:77
# self.lambda_:[[0.01532983]
#  [0.        ]
#  [0.        ]
#  [0.18061155]
#  [0.        ]
#  [0.        ]
#  [0.10552149]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06509413]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01052968]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:78
# self.lambda_:[[0.01447227]
#  [0.        ]
#  [0.        ]
#  [0.18223994]
#  [0.        ]
#  [0.        ]
#  [0.10556222]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06517414]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.01007204]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:79
# self.lambda_:[[0.01361209]
#  [0.        ]
#  [0.        ]
#  [0.18386697]
#  [0.        ]
#  [0.        ]
#  [0.10559945]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06525225]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00961392]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:80
# self.lambda_:[[0.01274962]
#  [0.        ]
#  [0.        ]
#  [0.1854928 ]
#  [0.        ]
#  [0.        ]
#  [0.10563359]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06532868]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00915538]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:81
# self.lambda_:[[0.01188512]
#  [0.        ]
#  [0.        ]
#  [0.18711756]
#  [0.        ]
#  [0.        ]
#  [0.10566503]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06540365]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00869648]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:82
# self.lambda_:[[0.01101884]
#  [0.        ]
#  [0.        ]
#  [0.1887414 ]
#  [0.        ]
#  [0.        ]
#  [0.10569409]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06547732]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00823727]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:83
# self.lambda_:[[0.010151  ]
#  [0.        ]
#  [0.        ]
#  [0.19036441]
#  [0.        ]
#  [0.        ]
#  [0.10572104]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06554986]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00777778]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:84
# self.lambda_:[[0.00928179]
#  [0.        ]
#  [0.        ]
#  [0.19198671]
#  [0.        ]
#  [0.        ]
#  [0.10574616]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0656214 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00731804]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:85
# self.lambda_:[[0.00841136]
#  [0.        ]
#  [0.        ]
#  [0.19360838]
#  [0.        ]
#  [0.        ]
#  [0.10576965]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06569207]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00685809]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:86
# self.lambda_:[[0.00753988]
#  [0.        ]
#  [0.        ]
#  [0.19522949]
#  [0.        ]
#  [0.        ]
#  [0.10579173]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06576196]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00639794]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:87
# self.lambda_:[[0.00666745]
#  [0.        ]
#  [0.        ]
#  [0.19685011]
#  [0.        ]
#  [0.        ]
#  [0.10581254]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06583118]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00593764]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:88
# self.lambda_:[[0.00579421]
#  [0.        ]
#  [0.        ]
#  [0.1984703 ]
#  [0.        ]
#  [0.        ]
#  [0.10583226]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0658998 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00547718]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:89
# self.lambda_:[[0.00492025]
#  [0.        ]
#  [0.        ]
#  [0.20009012]
#  [0.        ]
#  [0.        ]
#  [0.10585101]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06596789]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.0050166 ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:90
# self.lambda_:[[0.00404565]
#  [0.        ]
#  [0.        ]
#  [0.2017096 ]
#  [0.        ]
#  [0.        ]
#  [0.10586891]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06603553]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00455591]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:91
# self.lambda_:[[0.00317049]
#  [0.        ]
#  [0.        ]
#  [0.20332879]
#  [0.        ]
#  [0.        ]
#  [0.10588605]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06610275]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00409512]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:92
# self.lambda_:[[0.00229484]
#  [0.        ]
#  [0.        ]
#  [0.20494773]
#  [0.        ]
#  [0.        ]
#  [0.10590254]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06616963]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00363424]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:93
# self.lambda_:[[0.00141876]
#  [0.        ]
#  [0.        ]
#  [0.20656644]
#  [0.        ]
#  [0.        ]
#  [0.10591845]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06623619]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00317329]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:94
# self.lambda_:[[0.0005423 ]
#  [0.        ]
#  [0.        ]
#  [0.20818495]
#  [0.        ]
#  [0.        ]
#  [0.10593386]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06630247]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00271227]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:95
# self.lambda_:[[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.20979524]
#  [0.        ]
#  [0.        ]
#  [0.10593673]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06635894]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.002243  ]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:96
# self.lambda_:[[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.21138535]
#  [0.        ]
#  [0.        ]
#  [0.10590811]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06639119]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00175402]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:97
# self.lambda_:[[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.21295798]
#  [0.        ]
#  [0.        ]
#  [0.10584963]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06640195]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00124953]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:98
# self.lambda_:[[0.        ]
#  [0.        ]
#  [0.        ]
#  [0.21451529]
#  [0.        ]
#  [0.        ]
#  [0.10576314]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.06639357]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00073269]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# イテレーション回数i:99
# self.lambda_:[[0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [2.16059111e-01]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [1.05650575e-01]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [6.63680510e-02]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [2.05848643e-04]]
# self.lambda_.shape:(22, 1)
# X.shape:(22, 2)
# y.shape:(22,)
# テストデータXのサポートベクターself.X_sv:[[ 0.45261789 -1.78693033]
#  [ 3.00182069  1.23559938]
#  [-1.02691331  1.43290911]
#  [ 1.21528645  4.62867115]]
# テストデータｙのサポートベクターself.y_sv:[-1 -1  1  1]
# SV_pred:[-1  1  1  1 -1  1 -1 -1]
